# %% [markdown]
# # Data collection: Twitch Tracker
# There are several twitch analytics websites/projects which store historic Twitch data. These include:
# - TwitchTracker
# - SullyGnome
# - Social Blade
# - Twitchmetrics
# - Twitch Stats
# - StreamElements Chat Stats
# - Github repos (i.e. https://github.com/sid42/twitch-chat-analysis)
#
# Here we'll use Twitch Tracker to identify the top 2k streamers according to their total number of hours watched by users in the last 1 month. For each streamer we'll collect data on them such as their recent and career streaming metrics along with what games they tend to play.
#
# We use Selenium to collect the data. We've broken this process up into several functions.

# %%
# data processing
import json
import pandas as pd 

# Requests & web scraping
from selenium import webdriver      
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.keys import Keys
import urllib.request
from urllib.error import HTTPError

# miscellaneous
import os
from glob import glob
import time
import numpy as np
from collections import Counter
from datetime import datetime 

# settings
import config

# %% [markdown]
# ## Utilities

# %%
def rand_sleep(mean=4, std=1, lower=2.75, upper=5.25):
    # sleep for time distributed according to a truncated Gaussian distribution
    time.sleep(max(min(np.random.normal(loc=mean, scale=std), upper), lower)) 
    
def escape_ad(driver):
    webdriver.ActionChains(driver).send_keys(Keys.ESCAPE).perform()

# %% [markdown]
# ## Collect data on streamer's main page

# %%
# optional: get image
def get_img(driver, item_name):
    if not os.path.exists("data/streamer_logos/%s.png" % item_name):
        img = driver.find_element_by_xpath('.//div[@id="app-logo"]/img').get_attribute("src")
        try:
            urllib.request.urlretrieve(img, "data/streamer_logos/%s.png" % item_name)
        except HTTPError:
            print("Logo not available for", item_name)
        else:
            rand_sleep()

# %%
# click on "3 month" view of performance data
def get_performance_data(driver):
    summary_stats = driver.find_element_by_xpath('.//span[@data-key="3 months"]')
    summary_stats.click()
    rand_sleep(mean=0.5, std=0.1, lower=0.4, upper=0.8)

    performance_panel = driver.find_element_by_xpath('.//div[@id="performance-panel"]')
    performance_blocks = performance_panel.find_elements_by_xpath('.//div[@class="g-x-s-block"]')
    performance_data = []
    for block in performance_blocks:
        values = block.find_element_by_xpath('.//div[contains(@class,"g-x-s-value")]')
        values_divs = values.find_elements_by_xpath('.//div')
        contrast_val = values_divs[0].text.strip()
        actual_val = values_divs[1].find_elements_by_xpath('.//span')[0].text.strip()
        label = block.find_element_by_xpath('.//div[contains(@class,"g-x-s-label")]').text
        performance_data.append({label: [actual_val, contrast_val]})
    return performance_data

# %%
def get_summary_data(driver):
    summary_panel = driver.find_element_by_xpath('.//span[contains(text(),"Summary")]/ancestor::div[@class="container"]')
    summary_blocks = summary_panel.find_elements_by_xpath('.//div[@class="g-x-s-block"]')
    summary_data = []
    for block in summary_blocks:
        values = block.find_element_by_xpath('.//div[contains(@class,"g-x-s-value")]')
        values_divs = values.find_elements_by_xpath('.//div')
        actual_val = values_divs[-1].text
        label = block.find_element_by_xpath('.//div[contains(@class,"g-x-s-label")]').text
        summary_data.append({label: actual_val})
    return summary_data

# %%
def get_subscriber_data(driver):
    # Note: some channels do not have subscribe buttons. Furthermore, subscriber counts are hard to track and are not
    # reported for most channels
    subscriber_data = []
    try:
        subscriber_panel = driver.find_element_by_xpath('.//span[contains(text(),"Subscribers")]/ancestor::div[@class="container"]')
    except NoSuchElementException:
        print("Channel does not have a subscriber button or is missing subscriber info")
    else:
        subscriber_blocks = subscriber_panel.find_elements_by_xpath('.//div[@class="g-x-s-block"]')
        for block in subscriber_blocks:
            actual_val = block.find_element_by_xpath('.//div[@class="g-x-s-value"]').text
            label = block.find_element_by_xpath('.//div[contains(@class,"g-x-s-label")]').text
            subscriber_data.append({label: actual_val})
    return subscriber_data

# %%
def check_or_x(class_text):
    if "fa-check" in class_text:
        return "Yes"
    elif "fa-times" in class_text:
        return "No"
    else:
        return ""

def get_channel_desc(profile):
    two_last_lis = profile.find_elements_by_xpath('./li')[-2:]
    for li in two_last_lis:
        try:
            text = li.find_element_by_xpath('.//div[@style="word-wrap:break-word;font-size:12px;"]').text
            return text
        except:
            pass
    return ""
    
def get_profile_data(driver):
    # profile block
    profile = driver.find_element_by_xpath('.//div[contains(text(),"Streamer Profile")]/ancestor::ul[contains(@class,"list-group")]')

    # streamer name
    name = profile.find_element_by_xpath('.//div[@id="mini-profile"]/h4').text

    # 1 month algorithmic ranking
    ranking_1month = profile.find_element_by_xpath('.//div[contains(@title,"rank")]/b').text # overall ranking for last month                                             

    # streaming language
    language = profile.find_element_by_xpath('.//div[contains(text(),"Language")]/following-sibling::div/span').text

    # channel creation data
    created = profile.find_element_by_xpath('.//div[contains(text(),"Created")]/following-sibling::div/span').text

    # partnered
    partner_class = profile.find_element_by_xpath('.//span[contains(text(),"Partner")]/child::i').get_attribute('class')
    partner = check_or_x(partner_class)

    # mature content
    mature_class = profile.find_element_by_xpath('.//span[contains(text(),"Mature")]/child::i').get_attribute('class')
    mature = check_or_x(mature_class)

    # channel description
    channel_desc = get_channel_desc(profile)

    profile_data = [{"Name": name},
                    {"Ranking 1-month": ranking_1month},
                    {"Language": language},
                    {"Creation date": created},
                    {"Partnered": partner},
                    {"Mature content": mature},
                    {"Channel description": channel_desc}
                   ]
    return profile_data

# %%
def process_table(tr_list):
    output = []
    for tr in tr_list:
        tds = tr.find_elements_by_xpath('./td')
        label, value = tds[0].text, tds[1].text
        output.append({label: value})
    return output

def get_other_data(driver):
    # 2 additional tables
    average_stream = driver.find_elements_by_xpath('.//div[contains(text(),"Average Stream")]/parent::div/following-sibling::table/tbody/tr')                
    table1 = process_table(average_stream)
    various_metrics = driver.find_elements_by_xpath('.//div[contains(text(),"Various Metrics")]/parent::div/following-sibling::table/tbody/tr')
    table2 = process_table(various_metrics)
    return table1, table2

# %%
# save data
def save_streamer_data(item_name, performance_data, summary_data, subscriber_data, profile_data, table1, table2):
    full_data = {"Performance": performance_data, "Summary": summary_data, "Subscribers": subscriber_data, "Profile": profile_data,
                "Average stream": table1, "Various metrics": table2}
    
    with open('data/streamer_info/%s.json' % item_name, 'w') as f:
        json.dump(full_data, f)

# %%
def get_streamer_data(driver, item_name):
    time.sleep(0.2)
    escape_ad(driver)
    time.sleep(0.2)
    get_img(driver, item_name)
    performance_data = get_performance_data(driver)
    summary_data = get_summary_data(driver)
    subscriber_data = get_subscriber_data(driver)
    profile_data = get_profile_data(driver)
    table1, table2 = get_other_data(driver)
    save_streamer_data(item_name, performance_data, summary_data, subscriber_data, profile_data, table1, table2)

# %% [markdown]
# ## Collect data on streamer's "game" page

# %%
def get_game_data(driver, item_name):
    to_games = driver.find_element_by_xpath('.//div[@class="header-scope"]//a[contains(text(),"Games")]')
    to_games.click()
    escape_ad(driver)
    rand_sleep()

    # games table: we only extract the top 10 games
    table_headers = [th.text.strip() for th in driver.find_elements_by_xpath('.//table/thead/tr/th')]
    table_body = []
    table_body_rows = driver.find_elements_by_xpath('.//table/tbody/tr')
    for row in table_body_rows:
        table_body.append([td.text.strip() for td in row.find_elements_by_xpath('./td')])

    df = pd.DataFrame(data=table_body, columns=table_headers)
    df.to_csv("data/games/%s.csv" % item_name, mode="w", index=False)

# %%
def back_to_starting_page(driver):
    driver.back()
    time.sleep(0.1)
    escape_ad(driver)
    time.sleep(1)
    driver.back()
    time.sleep(0.1)
    escape_ad(driver)
    rand_sleep()

# %% [markdown]
# ## Get one full page of streamers

# %%
def get_one_page(driver, completed):
    time.sleep(0.1)
    escape_ad(driver)
    time.sleep(0.1)
    
    # get list of streamers on page 
    items = driver.find_elements_by_xpath('//div[@class="ranked-item"]')
    i = 0
    
    while i < len(items):
        link = items[i].find_element_by_xpath('.//div[@class="ri-name"]/a')
        i += 1
        item_name = link.text
        print("%i: %s" % (i, item_name))
        
        if item_name in completed:
            continue
        
        # go to streamer page
        driver.execute_script("arguments[0].scrollIntoView()", link)
        link.click()
        escape_ad(driver)
        rand_sleep()
        
        # get data
        get_streamer_data(driver, item_name)
        get_game_data(driver, item_name)
        
        # go back to start
        back_to_starting_page(driver)
        escape_ad(driver)
        items = driver.find_elements_by_xpath('//div[@class="ranked-item"]') # refresh stale reference

# %% [markdown]
# ## Get multiple pages

# %%
def get_multiple_pages(driver, starting_page, num_pages, completed):
    # starting page
#     url = "https://twitchtracker.com/channels/hours-watched?page=%i" % starting_page
    url = "https://twitchtracker.com/channels/hours-watched/english?page=%i" % starting_page
        
    # load the starting page
    driver.get(url)  
    rand_sleep()
    
    page_count = 0
    while page_count < num_pages:
        print("\n")
        print("Beginning page:", starting_page + page_count)
#         print("Pages remaining:", num_pages-starting_page-page_count+1)
        print("-"*20)
        get_one_page(driver, completed)
        next_page = driver.find_element_by_xpath('.//ul[contains(@class,"pagination")]/li[2]/a') 
        driver.execute_script("arguments[0].scrollIntoView()", next_page)
        time.sleep(0.1)
        next_page.click()
        rand_sleep(mean=20, std=7, lower=15, upper=30)
        page_count += 1

# %% [markdown]
# ## Running the script...

# %%
# initialize driver
driver = webdriver.Chrome('./chromedriver.exe')

# initialize headers for urllib.request
opener = urllib.request.build_opener()
opener.addheaders = [('User-agent', config.user_agent)]
urllib.request.install_opener(opener)

# completed = [] # starting new
completed = [x.split(".json")[0] for x in next(os.walk("data/streamer_info"))[2]] # resuming
get_multiple_pages(driver, starting_page=208, num_pages=250-208, completed=completed)
# Out:
# Beginning page: 113
# --------------------
# 1: Jynx
# Channel does not have a subscriber button or is missing subscriber info
# 2: Leffen
# Channel does not have a subscriber button or is missing subscriber info
# 3: x5_PiG
# Channel does not have a subscriber button or is missing subscriber info
# 4: benice92
# Channel does not have a subscriber button or is missing subscriber info
# 5: HekTic_JukeZ
# 6: Sajam
# Channel does not have a subscriber button or is missing subscriber info
# 7: imfrosk
# Channel does not have a subscriber button or is missing subscriber info
# 8: eskay
# Channel does not have a subscriber button or is missing subscriber info
# 9: Geef
# Channel does not have a subscriber button or is missing subscriber info
# 10: Slade
#
#
# Beginning page: 114
# --------------------
# 1: LiquidWiFi
# 2: DSKoopa
# Channel does not have a subscriber button or is missing subscriber info
# 3: Richard_Hammer
# Channel does not have a subscriber button or is missing subscriber info
# 4: Chanimaly
# Channel does not have a subscriber button or is missing subscriber info
# 5: xLie
# Channel does not have a subscriber button or is missing subscriber info
# 6: Hydramist
# Channel does not have a subscriber button or is missing subscriber info
# 7: Mitchflowerpower
# 8: DJFranzen
# Channel does not have a subscriber button or is missing subscriber info
# 9: djarii
# 10: JaboodyShow
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 115
# --------------------
# 1: Frozone
# Channel does not have a subscriber button or is missing subscriber info
# 2: foggedftw2
# Channel does not have a subscriber button or is missing subscriber info
# 3: Aipha
# Channel does not have a subscriber button or is missing subscriber info
# 4: ImperiumNews
# Channel does not have a subscriber button or is missing subscriber info
# 5: Bum1six3
# Channel does not have a subscriber button or is missing subscriber info
# 6: JonSandman
# Channel does not have a subscriber button or is missing subscriber info
# 7: Bananasaurus_Rex
# Channel does not have a subscriber button or is missing subscriber info
# 8: Aniemal
# Channel does not have a subscriber button or is missing subscriber info
# 9: GoneDoc
# Channel does not have a subscriber button or is missing subscriber info
# 10: Mister_Hooks
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 116
# --------------------
# 1: Wookie_Legend
# 2: enotishka18
# Channel does not have a subscriber button or is missing subscriber info
# 3: JasonSulli
# Channel does not have a subscriber button or is missing subscriber info
# 4: ScrubNoob
# Channel does not have a subscriber button or is missing subscriber info
# 5: poofesure
# Channel does not have a subscriber button or is missing subscriber info
# 6: MarketTradersTV
# Channel does not have a subscriber button or is missing subscriber info
# 7: kevinmartin
# Channel does not have a subscriber button or is missing subscriber info
# 8: CyberLiveArena4
# Channel does not have a subscriber button or is missing subscriber info
# 9: gabrielanddresden
# Channel does not have a subscriber button or is missing subscriber info
# 10: matthewkheafy
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 117
# --------------------
# 1: nasher
# Channel does not have a subscriber button or is missing subscriber info
# 2: WorldGamblingLeague
# Channel does not have a subscriber button or is missing subscriber info
# 3: gusjohnson
# Channel does not have a subscriber button or is missing subscriber info
# 4: bchillz
# 5: Kreo
# Channel does not have a subscriber button or is missing subscriber info
# 6: SeriousGaming
# Channel does not have a subscriber button or is missing subscriber info
# 7: Boneclinks
# 8: Ki11erSix
# Channel does not have a subscriber button or is missing subscriber info
# 9: NicHeroes
# Channel does not have a subscriber button or is missing subscriber info
# 10: Bandsintown
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 118
# --------------------
# 1: Techniq
# Channel does not have a subscriber button or is missing subscriber info
# 2: MegaM0gwai
# Channel does not have a subscriber button or is missing subscriber info
# 3: WOKE
# Channel does not have a subscriber button or is missing subscriber info
# 4: AnderZEL
# Channel does not have a subscriber button or is missing subscriber info
# 5: lleagerll
# Logo not available for lleagerll
# Channel does not have a subscriber button or is missing subscriber info
# 6: RPGLimitBreak
# Channel does not have a subscriber button or is missing subscriber info
# 7: KawaiiNekoWaifu
# 8: LaurenzSide
# Channel does not have a subscriber button or is missing subscriber info
# 9: RequiemSlaps
# Channel does not have a subscriber button or is missing subscriber info
# 10: JessuTV
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 119
# --------------------
# 1: Cheesur
# Channel does not have a subscriber button or is missing subscriber info
# 2: MattStaples
# Channel does not have a subscriber button or is missing subscriber info
# 3: Worrun_
# 4: Gunnermaniac
# Channel does not have a subscriber button or is missing subscriber info
# 5: Sharptooth
# Channel does not have a subscriber button or is missing subscriber info
# 6: HashtagTom_
# Channel does not have a subscriber button or is missing subscriber info
# 7: SnaggyMo
# Channel does not have a subscriber button or is missing subscriber info
# 8: theneedledrop
# 9: Amaz
# 10: Zentreya
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 120
# --------------------
# 1: joeytuan
# 2: Insym
# Channel does not have a subscriber button or is missing subscriber info
# 3: DreamHackPUBG
# Channel does not have a subscriber button or is missing subscriber info
# 4: FUTWIZ_Jamodo
# Channel does not have a subscriber button or is missing subscriber info
# 5: Covent
# Channel does not have a subscriber button or is missing subscriber info
# 6: jenniepike1993
# Channel does not have a subscriber button or is missing subscriber info
# 7: fuzzface49
# Channel does not have a subscriber button or is missing subscriber info
# 8: NivUltra
# Channel does not have a subscriber button or is missing subscriber info
# 9: Scrub
# Channel does not have a subscriber button or is missing subscriber info
# 10: fifaanalyst
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 121
# --------------------
# 1: Gtv111_
# Channel does not have a subscriber button or is missing subscriber info
# 2: Tylerootd
# Channel does not have a subscriber button or is missing subscriber info
# 3: PsychoxDH
# Channel does not have a subscriber button or is missing subscriber info
# 4: Fragnance
# Channel does not have a subscriber button or is missing subscriber info
# 5: Koogs46
# Channel does not have a subscriber button or is missing subscriber info
# 6: DADDY_LAW_69
# Channel does not have a subscriber button or is missing subscriber info
# 7: bostonWEEI
# Channel does not have a subscriber button or is missing subscriber info
# 8: Waggle
# Channel does not have a subscriber button or is missing subscriber info
# 9: Egption
# Channel does not have a subscriber button or is missing subscriber info
# 10: ItsSky
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 122
# --------------------
# 1: Arkhram
# Channel does not have a subscriber button or is missing subscriber info
# 2: MsAshRocks
# Channel does not have a subscriber button or is missing subscriber info
# 3: LoadingReadyRun
# Channel does not have a subscriber button or is missing subscriber info
# 4: Sneegsnag
# Channel does not have a subscriber button or is missing subscriber info
# 5: yvonnie
# Channel does not have a subscriber button or is missing subscriber info
# 6: TEKKEN
# Channel does not have a subscriber button or is missing subscriber info
# 7: Repullze
# 8: Macaw45
# Channel does not have a subscriber button or is missing subscriber info
# 9: erickthearchitect
# Channel does not have a subscriber button or is missing subscriber info
# 10: Swag_Dracula
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 123
# --------------------
# 1: CyberLiveArena6
# Channel does not have a subscriber button or is missing subscriber info
# 2: WizDaKidd__
# Channel does not have a subscriber button or is missing subscriber info
# 3: Zmok
# Channel does not have a subscriber button or is missing subscriber info
# 4: PizzaHS
# Channel does not have a subscriber button or is missing subscriber info
# 5: rabbittvlittlegirl
# Channel does not have a subscriber button or is missing subscriber info
# 6: UnRooolie
# Channel does not have a subscriber button or is missing subscriber info
# 7: Mushu
# 8: PaladinsGame
# Channel does not have a subscriber button or is missing subscriber info
# 9: GTAWiseGuy
# 10: d0cc_tv
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 124
# --------------------
# 1: americandadtv36
# Channel does not have a subscriber button or is missing subscriber info
# 2: OVOPhantuums
# Channel does not have a subscriber button or is missing subscriber info
# 3: Warcraft
# Channel does not have a subscriber button or is missing subscriber info
# 4: chell
# Channel does not have a subscriber button or is missing subscriber info
# 5: n3on
# Channel does not have a subscriber button or is missing subscriber info
# 6: NiceTwice
# Channel does not have a subscriber button or is missing subscriber info
# 7: REDami
# Channel does not have a subscriber button or is missing subscriber info
# 8: PureChiLL
# Channel does not have a subscriber button or is missing subscriber info
# 9: xFSN_Saber
# Channel does not have a subscriber button or is missing subscriber info
# 10: Manni2
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 125
# --------------------
# 1: ItsJSTN
# Channel does not have a subscriber button or is missing subscriber info
# 2: EvilGeniuses
# Channel does not have a subscriber button or is missing subscriber info
# 3: bekzzo
# 4: DevinNash
# Channel does not have a subscriber button or is missing subscriber info
# 5: Whaazz
# Channel does not have a subscriber button or is missing subscriber info
# 6: FreeMasonLive
# Channel does not have a subscriber button or is missing subscriber info
# 7: Ecdycis
# Channel does not have a subscriber button or is missing subscriber info
# 8: Runebee
# Channel does not have a subscriber button or is missing subscriber info
# 9: rnpcasino
# Channel does not have a subscriber button or is missing subscriber info
# 10: CallOfCthulhu
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 126
# --------------------
# 1: CopyKat_
# Channel does not have a subscriber button or is missing subscriber info
# 2: LotharHS
# 3: Suto
# Channel does not have a subscriber button or is missing subscriber info
# 4: dafran
# 5: JohnWolfe
# Channel does not have a subscriber button or is missing subscriber info
# 6: computerchess
# Channel does not have a subscriber button or is missing subscriber info
# 7: Savix
# Channel does not have a subscriber button or is missing subscriber info
# 8: Moadmoad
# Channel does not have a subscriber button or is missing subscriber info
# 9: BigJon
# 10: LetsGiveItASpin
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 127
# --------------------
# 1: DavidPakman
# Channel does not have a subscriber button or is missing subscriber info
# 2: Electra
# Channel does not have a subscriber button or is missing subscriber info
# 3: jazminireland1988
# Channel does not have a subscriber button or is missing subscriber info
# 4: Captainflowers22
# Channel does not have a subscriber button or is missing subscriber info
# 5: TheMexicanRunner
# Channel does not have a subscriber button or is missing subscriber info
# 6: Nerdi
# Channel does not have a subscriber button or is missing subscriber info
# 7: Quirkitized
# Channel does not have a subscriber button or is missing subscriber info
# 8: ESL_CSGOc
# Channel does not have a subscriber button or is missing subscriber info
# 9: febbydoto
# Channel does not have a subscriber button or is missing subscriber info
# 10: ibiza
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 128
# --------------------
# 1: Bobonei
# Channel does not have a subscriber button or is missing subscriber info
# 2: LiquidHasuObs
# Channel does not have a subscriber button or is missing subscriber info
# 3: MadDecentLive
# Channel does not have a subscriber button or is missing subscriber info
# 4: Carmen
# Channel does not have a subscriber button or is missing subscriber info
# 5: poisonedpotion
# 6: LyndonFPS
# Channel does not have a subscriber button or is missing subscriber info
# 7: HashtagUnited
# Channel does not have a subscriber button or is missing subscriber info
# 8: HoggsyTheHoarder
# Channel does not have a subscriber button or is missing subscriber info
# 9: Cowsep
# 10: TwoAngryGamersTV
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 129
# --------------------
# 1: Alliestrasza
# Channel does not have a subscriber button or is missing subscriber info
# 2: BROBQ
# 3: dubs
# Channel does not have a subscriber button or is missing subscriber info
# 4: Saiiren
# Channel does not have a subscriber button or is missing subscriber info
# 5: Calfreezy
# Channel does not have a subscriber button or is missing subscriber info
# 6: jessica
# Channel does not have a subscriber button or is missing subscriber info
# 7: Cardboard_Cowboy
# Channel does not have a subscriber button or is missing subscriber info
# 8: Yeatle
# Channel does not have a subscriber button or is missing subscriber info
# 9: watchmeblink
# Channel does not have a subscriber button or is missing subscriber info
# 10: Gabbie
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 130
# --------------------
# 1: astro
# Channel does not have a subscriber button or is missing subscriber info
# 2: coxie
# Channel does not have a subscriber button or is missing subscriber info
# 3: Byzic
# Channel does not have a subscriber button or is missing subscriber info
# 4: MisMagpie
# Channel does not have a subscriber button or is missing subscriber info
# 5: AnthonyCaliber
# Channel does not have a subscriber button or is missing subscriber info
# 6: Monkeynews
# Channel does not have a subscriber button or is missing subscriber info
# 7: Indrek
# Channel does not have a subscriber button or is missing subscriber info
# 8: ViBElol
# Channel does not have a subscriber button or is missing subscriber info
# 9: haelian
# Channel does not have a subscriber button or is missing subscriber info
# 10: Axel_tv
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 131
# --------------------
# 1: CODMobile
# Channel does not have a subscriber button or is missing subscriber info
# 2: VarsityGaming
# Channel does not have a subscriber button or is missing subscriber info
# 3: Graycen
# Channel does not have a subscriber button or is missing subscriber info
# 4: SpawnOnMe
# Channel does not have a subscriber button or is missing subscriber info
# 5: Nakkida
# 6: ASMR_Marie
# Channel does not have a subscriber button or is missing subscriber info
# 7: Ninjayla
# Channel does not have a subscriber button or is missing subscriber info
# 8: Elix
# 9: AxialMatt
# Channel does not have a subscriber button or is missing subscriber info
# 10: LotusAsakura
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 132
# --------------------
# 1: BiggYBlains
# Channel does not have a subscriber button or is missing subscriber info
# 2: HazelNuttyGames
# Channel does not have a subscriber button or is missing subscriber info
# 3: Zfg1
# Channel does not have a subscriber button or is missing subscriber info
# 4: LigaPro2
# Channel does not have a subscriber button or is missing subscriber info
# 5: Blaustoise
# Channel does not have a subscriber button or is missing subscriber info
# 6: IMPACTWrestling
# Channel does not have a subscriber button or is missing subscriber info
# 7: LigaPro8
# Channel does not have a subscriber button or is missing subscriber info
# 8: BoiseStateUniversity
# Channel does not have a subscriber button or is missing subscriber info
# 9: JKap
# Channel does not have a subscriber button or is missing subscriber info
# 10: KindaFunnyGames
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 133
# --------------------
# 1: Autumn_VR
# Channel does not have a subscriber button or is missing subscriber info
# 2: NoResetSpeedrun
# Channel does not have a subscriber button or is missing subscriber info
# 3: nouvellesdespatriotes
# Channel does not have a subscriber button or is missing subscriber info
# 4: Lt_Custard
# Channel does not have a subscriber button or is missing subscriber info
# 5: PlayStation
# Channel does not have a subscriber button or is missing subscriber info
# 6: AnnieBot
# 7: ytzaxy
# Channel does not have a subscriber button or is missing subscriber info
# 8: Mendo
# 9: Surefour
# 10: SMii7Y
#
#
# Beginning page: 134
# --------------------
# 1: Polecat324
# Channel does not have a subscriber button or is missing subscriber info
# 2: Suspect
# Channel does not have a subscriber button or is missing subscriber info
# 3: Goofy757
# Channel does not have a subscriber button or is missing subscriber info
# 4: NorthTaisheen
# Channel does not have a subscriber button or is missing subscriber info
# 5: Apocalypto_12
# Channel does not have a subscriber button or is missing subscriber info
# 6: OfficialTaco
# Channel does not have a subscriber button or is missing subscriber info
# 7: BenFruit
# Channel does not have a subscriber button or is missing subscriber info
# 8: Vicksy
# Channel does not have a subscriber button or is missing subscriber info
# 9: 4Conner
# Channel does not have a subscriber button or is missing subscriber info
# 10: papasmakcheeks
#
#
# Beginning page: 135
# --------------------
# 1: EnderCasts
# Channel does not have a subscriber button or is missing subscriber info
# 2: PatrckStatic
# Channel does not have a subscriber button or is missing subscriber info
# 3: fwypsuktzbcagpc
# Channel does not have a subscriber button or is missing subscriber info
# 4: Mexi
# Channel does not have a subscriber button or is missing subscriber info
# 5: demisux
# Channel does not have a subscriber button or is missing subscriber info
# 6: crouching_tuna
# Channel does not have a subscriber button or is missing subscriber info
# 7: DotaTV247
# Channel does not have a subscriber button or is missing subscriber info
# 8: ESPN1000Chicago
# Channel does not have a subscriber button or is missing subscriber info
# 9: Teawrex
# Channel does not have a subscriber button or is missing subscriber info
# 10: CritterVision
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 136
# --------------------
# 1: DropsByPonk
# Channel does not have a subscriber button or is missing subscriber info
# 2: Maxylobes
# Channel does not have a subscriber button or is missing subscriber info
# 3: Hitbotc
# Channel does not have a subscriber button or is missing subscriber info
# 4: TheShowstopper
# Channel does not have a subscriber button or is missing subscriber info
# 5: CarlSagan42
# Channel does not have a subscriber button or is missing subscriber info
# 6: Kobe0802
# 7: NicMakesPlays
# Channel does not have a subscriber button or is missing subscriber info
# 8: Curvyllama
# 9: Vinc3ntvega
# 10: luality
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 137
# --------------------
# 1: StatsBloke
# Channel does not have a subscriber button or is missing subscriber info
# 2: tobzleronehd
# 3: Renegades
# Channel does not have a subscriber button or is missing subscriber info
# 4: jonny
# Channel does not have a subscriber button or is missing subscriber info
# 5: ToD
# Channel does not have a subscriber button or is missing subscriber info
# 6: TaehaTypes
# 7: syndereN
# Channel does not have a subscriber button or is missing subscriber info
# 8: Venalis
# Channel does not have a subscriber button or is missing subscriber info
# 9: Harrie
# Channel does not have a subscriber button or is missing subscriber info
# 10: Irenealing
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 138
# --------------------
# 1: JadetheJaguar
# Channel does not have a subscriber button or is missing subscriber info
# 2: ImMadness
# Channel does not have a subscriber button or is missing subscriber info
# 3: fruity
# Channel does not have a subscriber button or is missing subscriber info
# 4: TCEC_Chess_TV
# Channel does not have a subscriber button or is missing subscriber info
# 5: publ1c3nemy_ttv_
# Channel does not have a subscriber button or is missing subscriber info
# 6: NoHaileeNo
# Channel does not have a subscriber button or is missing subscriber info
# 7: TheRealPugzilla
# Channel does not have a subscriber button or is missing subscriber info
# 8: TehJamJar
# Channel does not have a subscriber button or is missing subscriber info
# 9: Baalorlord
# Channel does not have a subscriber button or is missing subscriber info
# 10: osulive
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 139
# --------------------
# 1: Russel
# Channel does not have a subscriber button or is missing subscriber info
# 2: JoelCP_
# Channel does not have a subscriber button or is missing subscriber info
# 3: Teeqo
# Channel does not have a subscriber button or is missing subscriber info
# 4: DrSteinman
# Channel does not have a subscriber button or is missing subscriber info
# 5: BlueandQueenie
# 6: CyanidePlaysGames
# Channel does not have a subscriber button or is missing subscriber info
# 7: GMHess
# Channel does not have a subscriber button or is missing subscriber info
# 8: Akademiks
# Channel does not have a subscriber button or is missing subscriber info
# 9: Miss_Rage
# Channel does not have a subscriber button or is missing subscriber info
# 10: navioot
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 140
# --------------------
# 1: Avery
# Channel does not have a subscriber button or is missing subscriber info
# 2: TheoHS_
# Channel does not have a subscriber button or is missing subscriber info
# 3: Jaee
# Logo not available for Jaee
# Channel does not have a subscriber button or is missing subscriber info
# 4: Tayynyc
# 5: steel_tv
# 6: hanner
# Channel does not have a subscriber button or is missing subscriber info
# 7: Svennoss
# Channel does not have a subscriber button or is missing subscriber info
# 8: Baker
# Channel does not have a subscriber button or is missing subscriber info
# 9: GeT_RiGhT
# Channel does not have a subscriber button or is missing subscriber info
# 10: TwitchPlaysPokemon
#
#
# Beginning page: 141
# --------------------
# 1: ds_lily
# Channel does not have a subscriber button or is missing subscriber info
# 2: xtony_t_x
# Channel does not have a subscriber button or is missing subscriber info
# 3: ggGibi
# Channel does not have a subscriber button or is missing subscriber info
# 4: Fireburner
# Channel does not have a subscriber button or is missing subscriber info
# 5: genericgamings
# Channel does not have a subscriber button or is missing subscriber info
# 6: SkiddlerRS
# Channel does not have a subscriber button or is missing subscriber info
# 7: samsungus
# Channel does not have a subscriber button or is missing subscriber info
# 8: Necros
# Channel does not have a subscriber button or is missing subscriber info
# 9: Pixlriffs
# Channel does not have a subscriber button or is missing subscriber info
# 10: WorldPokerTour
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 142
# --------------------
# 1: JadeyAnh
# 2: GMBenjaminFinegold
# Channel does not have a subscriber button or is missing subscriber info
# 3: Anjuna
# Channel does not have a subscriber button or is missing subscriber info
# 4: Squirrel
# Channel does not have a subscriber button or is missing subscriber info
# 5: Sjeletyven1
# Channel does not have a subscriber button or is missing subscriber info
# 6: DailyDasher
# Channel does not have a subscriber button or is missing subscriber info
# 7: TheDanDangler
# 8: Apathy
# Channel does not have a subscriber button or is missing subscriber info
# 9: lol_nemesis
# Channel does not have a subscriber button or is missing subscriber info
# 10: APlatypuss
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 143
# --------------------
# 1: HeroesHearth
# Channel does not have a subscriber button or is missing subscriber info
# 2: JSmoothHD
# Channel does not have a subscriber button or is missing subscriber info
# 3: jaycgee
# Channel does not have a subscriber button or is missing subscriber info
# 4: reiderrabbit
# Channel does not have a subscriber button or is missing subscriber info
# 5: ELEAGUE TV
# Channel does not have a subscriber button or is missing subscriber info
# 6: paxahau
# Channel does not have a subscriber button or is missing subscriber info
# 7: Frosty
# Channel does not have a subscriber button or is missing subscriber info
# 8: UnrealYuki
# Channel does not have a subscriber button or is missing subscriber info
# 9: HatFilms
# Channel does not have a subscriber button or is missing subscriber info
# 10: fineokay
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 144
# --------------------
# 1: kkonvy
# Channel does not have a subscriber button or is missing subscriber info
# 2: Xisuma
# Channel does not have a subscriber button or is missing subscriber info
# 3: Orzanel
# Channel does not have a subscriber button or is missing subscriber info
# 4: DreamHackFN
# Channel does not have a subscriber button or is missing subscriber info
# 5: KayPea
# 6: FilthyRobot
# 7: OaksLab
# Channel does not have a subscriber button or is missing subscriber info
# 8: gigi
# Channel does not have a subscriber button or is missing subscriber info
# 9: propunker
# Channel does not have a subscriber button or is missing subscriber info
# 10: GiantBomb
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 145
# --------------------
# 1: Veritas
# Channel does not have a subscriber button or is missing subscriber info
# 2: hyoon
# Channel does not have a subscriber button or is missing subscriber info
# 3: SwInD
# Channel does not have a subscriber button or is missing subscriber info
# 4: VERTiiGOGAMING
# Channel does not have a subscriber button or is missing subscriber info
# 5: LEGIQN
# Channel does not have a subscriber button or is missing subscriber info
# 6: Brozime
# Channel does not have a subscriber button or is missing subscriber info
# 7: Awkwards_Travel
# 8: RandomRambo
# 9: OmegaPro
# Channel does not have a subscriber button or is missing subscriber info
# 10: TeamBeyondnet
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 146
# --------------------
# 1: Catonmarz
# Channel does not have a subscriber button or is missing subscriber info
# 2: Jeathebelle
# Channel does not have a subscriber button or is missing subscriber info
# 3: Dirty
# Channel does not have a subscriber button or is missing subscriber info
# 4: OurChickenLife
# 5: Lyndi
# Channel does not have a subscriber button or is missing subscriber info
# 6: easywithaces
# Channel does not have a subscriber button or is missing subscriber info
# 7: MightyTeapot
# Channel does not have a subscriber button or is missing subscriber info
# 8: Cloud_805
# 9: Feyd
# 10: Larxa
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 147
# --------------------
# 1: mxmtoon
# Channel does not have a subscriber button or is missing subscriber info
# 2: Dekel
# 3: RabiesTV
# Channel does not have a subscriber button or is missing subscriber info
# 4: Arthars
# Channel does not have a subscriber button or is missing subscriber info
# 5: Vaerinis
# Channel does not have a subscriber button or is missing subscriber info
# 6: Deisik
# Channel does not have a subscriber button or is missing subscriber info
# 7: sirfoch
# Channel does not have a subscriber button or is missing subscriber info
# 8: xPopularStranger
# Channel does not have a subscriber button or is missing subscriber info
# 9: TeamLiquid
# Channel does not have a subscriber button or is missing subscriber info
# 10: Pyrionflax
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 148
# --------------------
# 1: SarahKey
# Channel does not have a subscriber button or is missing subscriber info
# 2: SpeedrunHypeTV
# Channel does not have a subscriber button or is missing subscriber info
# 3: JtunesGaming
# Channel does not have a subscriber button or is missing subscriber info
# 4: ashlizzlle
# Channel does not have a subscriber button or is missing subscriber info
# 5: NickiTaylor
# 6: Ron_Plays_Games
# Channel does not have a subscriber button or is missing subscriber info
# 7: YamatosDeath1
# Channel does not have a subscriber button or is missing subscriber info
# 8: NediaVR
# Channel does not have a subscriber button or is missing subscriber info
# 9: Glorious_E
# Channel does not have a subscriber button or is missing subscriber info
# 10: exzachtt
#
#
# Beginning page: 149
# --------------------
# 1: n0ted
# 2: EternaLEnVyy
# Channel does not have a subscriber button or is missing subscriber info
# 3: Pineaqples
# Channel does not have a subscriber button or is missing subscriber info
# 4: aleks
# Channel does not have a subscriber button or is missing subscriber info
# 5: GP_TV
# Channel does not have a subscriber button or is missing subscriber info
# 6: tinylady
# Channel does not have a subscriber button or is missing subscriber info
# 7: OkCode
# Channel does not have a subscriber button or is missing subscriber info
# 8: aspiringspike
# Channel does not have a subscriber button or is missing subscriber info
# 9: FakeUniforM
# Channel does not have a subscriber button or is missing subscriber info
# 10: Wavy
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 150
# --------------------
# 1: AmericanDad
# Channel does not have a subscriber button or is missing subscriber info
# 2: CDawg_VA
# Channel does not have a subscriber button or is missing subscriber info
# 3: snyuunu
# Channel does not have a subscriber button or is missing subscriber info
# 4: gdolphn
# Channel does not have a subscriber button or is missing subscriber info
# 5: Attackerdota
# Channel does not have a subscriber button or is missing subscriber info
# 6: six_cyx
# Channel does not have a subscriber button or is missing subscriber info
# 7: angelicuh
# Channel does not have a subscriber button or is missing subscriber info
# 8: KojisRevenge
# 9: Serato
# Channel does not have a subscriber button or is missing subscriber info
# 10: Thorlar
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 151
# --------------------
# 1: AutomaticJak
# Channel does not have a subscriber button or is missing subscriber info
# 2: harkdan
# Channel does not have a subscriber button or is missing subscriber info
# 3: JohnnyCanal
# Channel does not have a subscriber button or is missing subscriber info
# 4: woops
# 5: Lawlman
# Channel does not have a subscriber button or is missing subscriber info
# 6: Etup
# Channel does not have a subscriber button or is missing subscriber info
# 7: BigDaddy
# Channel does not have a subscriber button or is missing subscriber info
# 8: Itani
# 9: AlanAvi_
# Channel does not have a subscriber button or is missing subscriber info
# 10: 2BCSuperb
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 152
# --------------------
# 1: RegisKillbin
# Channel does not have a subscriber button or is missing subscriber info
# 2: ExcessiveProfanity
# Channel does not have a subscriber button or is missing subscriber info
# 3: THEIR0NJEW
# Channel does not have a subscriber button or is missing subscriber info
# 4: WD_BLACK
# Channel does not have a subscriber button or is missing subscriber info
# 5: ybnbluee
# Channel does not have a subscriber button or is missing subscriber info
# 6: flutterchan
# Channel does not have a subscriber button or is missing subscriber info
# 7: codey
# Channel does not have a subscriber button or is missing subscriber info
# 8: QuickReviewShow
# Channel does not have a subscriber button or is missing subscriber info
# 9: SharonQueen
# Channel does not have a subscriber button or is missing subscriber info
# 10: PandaCat
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 153
# --------------------
# 1: Lucroan
# Channel does not have a subscriber button or is missing subscriber info
# 2: themajorityreport
# Channel does not have a subscriber button or is missing subscriber info
# 3: jccaylen
# Channel does not have a subscriber button or is missing subscriber info
# 4: iskall85
# Channel does not have a subscriber button or is missing subscriber info
# 5: Sizz
# Channel does not have a subscriber button or is missing subscriber info
# 6: LostResortTV
# Channel does not have a subscriber button or is missing subscriber info
# 7: BradWOTO
# Channel does not have a subscriber button or is missing subscriber info
# 8: Rallied
# Channel does not have a subscriber button or is missing subscriber info
# 9: GeneralSniperNA
# Channel does not have a subscriber button or is missing subscriber info
# 10: littlesiha
# Channel does not have a subscriber button or is missing subscriber info
# Beginning page: 154
# --------------------
# 1: lethamyr_rl
# Channel does not have a subscriber button or is missing subscriber info
# 2: justfoxii
# Channel does not have a subscriber button or is missing subscriber info
# 3: EnragedCinema
# Channel does not have a subscriber button or is missing subscriber info
# 4: AtomicTwins
# Channel does not have a subscriber button or is missing subscriber info
# 5: ybnmikey
# Channel does not have a subscriber button or is missing subscriber info
# 6: DauT
# Channel does not have a subscriber button or is missing subscriber info
# 7: Razer
# Channel does not have a subscriber button or is missing subscriber info
# 8: AutolykusLoL
# Channel does not have a subscriber button or is missing subscriber info
# 9: Tolomeo
# Channel does not have a subscriber button or is missing subscriber info
# 10: Capp
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 155
# --------------------
# 1: ARUUU
# Channel does not have a subscriber button or is missing subscriber info
# 2: ThumblessCudi
# Channel does not have a subscriber button or is missing subscriber info
# 3: jeemzz
# Channel does not have a subscriber button or is missing subscriber info
# 4: scuffed_pc
# 5: JoltzDude139
# Channel does not have a subscriber button or is missing subscriber info
# 6: GubbaTV
# Channel does not have a subscriber button or is missing subscriber info
# 7: JackTheRipperGB
# Channel does not have a subscriber button or is missing subscriber info
# 8: psalm
# Channel does not have a subscriber button or is missing subscriber info
# 9: BBXH
# Channel does not have a subscriber button or is missing subscriber info
# 10: Amazonian
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 156
# --------------------
# 1: LaserBelch
# Channel does not have a subscriber button or is missing subscriber info
# 2: cheese
# Channel does not have a subscriber button or is missing subscriber info
# 3: Dakkroth
# Channel does not have a subscriber button or is missing subscriber info
# 4: ElichTV
# Channel does not have a subscriber button or is missing subscriber info
# 5: Yuuie
# Channel does not have a subscriber button or is missing subscriber info
# 6: Pieman
# 7: CantaPerMe92
# Channel does not have a subscriber button or is missing subscriber info
# 8: CrookedNoseMedia
# Channel does not have a subscriber button or is missing subscriber info
# 9: NoFoodAfterMidnight
# 10: SpeedGaming
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 157
# --------------------
# 1: KargozGaming
# Channel does not have a subscriber button or is missing subscriber info
# 2: Octavian0
# Channel does not have a subscriber button or is missing subscriber info
# 3: Sattelizer
# 4: AngryTestie
# Channel does not have a subscriber button or is missing subscriber info
# 5: Lawlman
# Channel does not have a subscriber button or is missing subscriber info
# 6: ItsBondx
# Channel does not have a subscriber button or is missing subscriber info
# 7: Zulu
# Channel does not have a subscriber button or is missing subscriber info
# 8: Marzzzzy
# Channel does not have a subscriber button or is missing subscriber info
# 9: travisgafford
# Channel does not have a subscriber button or is missing subscriber info
# 10: MadDecentLive
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 158
# --------------------
# 1: SDShepard
# Channel does not have a subscriber button or is missing subscriber info
# 2: scuffed_pc
# 3: GubbaTV
# Channel does not have a subscriber button or is missing subscriber info
# 4: ThumblessCudi
# Channel does not have a subscriber button or is missing subscriber info
# 5: InceptionXx
# Channel does not have a subscriber button or is missing subscriber info
# 6: AmazonMusicUK
# Channel does not have a subscriber button or is missing subscriber info
# 7: Ettnix
# Channel does not have a subscriber button or is missing subscriber info
# 8: RabiesTV
# Channel does not have a subscriber button or is missing subscriber info
# 9: AutolykusLoL
# Channel does not have a subscriber button or is missing subscriber info
# 10: TSM_Reps
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 159
# --------------------
# 1: littlesiha
# Channel does not have a subscriber button or is missing subscriber info
# 2: BradWOTO
# Channel does not have a subscriber button or is missing subscriber info
# 3: mismatchedsocksss
# Channel does not have a subscriber button or is missing subscriber info
# 4: AutomaticJak
# Channel does not have a subscriber button or is missing subscriber info
# 5: Jessie
# 6: usedpizza
# Channel does not have a subscriber button or is missing subscriber info
# 7: Cris
# Channel does not have a subscriber button or is missing subscriber info
# 8: J4CKIECHAN
# Channel does not have a subscriber button or is missing subscriber info
# 9: ElichTV
# Channel does not have a subscriber button or is missing subscriber info
# 10: geenelly
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 160
# --------------------
# 1: TheSerfsTV
# Channel does not have a subscriber button or is missing subscriber info
# 2: NoFoodAfterMidnight
# 3: TSM_Commandment
# Channel does not have a subscriber button or is missing subscriber info
# 4: Sereda
# Channel does not have a subscriber button or is missing subscriber info
# 5: Gigz
# Channel does not have a subscriber button or is missing subscriber info
# 6: Ekuegan
# 7: dippedinpoison
# 8: KarQ
# 9: Dimeax
# Channel does not have a subscriber button or is missing subscriber info
# 10: Pieman
#
#
# Beginning page: 161
# --------------------
# 1: MrRapolas
# Channel does not have a subscriber button or is missing subscriber info
# 2: Jabroni_Mike
# Channel does not have a subscriber button or is missing subscriber info
# 3: Deisik
# Channel does not have a subscriber button or is missing subscriber info
# 4: Demonifying
# 5: sYnceDez
# Channel does not have a subscriber button or is missing subscriber info
# 6: F1NN5TER
# Channel does not have a subscriber button or is missing subscriber info
# 7: Yerv
# Channel does not have a subscriber button or is missing subscriber info
# 8: MMG69
# Channel does not have a subscriber button or is missing subscriber info
# 9: Yungstaz
# Channel does not have a subscriber button or is missing subscriber info
# 10: xBaronful
#
#
# Beginning page: 162
# --------------------
# 1: TaySon
# Channel does not have a subscriber button or is missing subscriber info
# 2: sparkles_qt
# Channel does not have a subscriber button or is missing subscriber info
# 3: speros_
# Channel does not have a subscriber button or is missing subscriber info
# 4: CantaPerMe92
# Channel does not have a subscriber button or is missing subscriber info
# 5: Tangent
# Channel does not have a subscriber button or is missing subscriber info
# 6: IcyRayne
# Channel does not have a subscriber button or is missing subscriber info
# 7: Neuro
# Channel does not have a subscriber button or is missing subscriber info
# 8: Juuu
# Channel does not have a subscriber button or is missing subscriber info
# 9: EternaLEnVyy
# Channel does not have a subscriber button or is missing subscriber info
# 10: TobyontheTele
#
#
# Beginning page: 163
# --------------------
# 1: JeffHoogland
# Channel does not have a subscriber button or is missing subscriber info
# 2: MrKoolaidofficial
# Channel does not have a subscriber button or is missing subscriber info
# 3: MassNarX
# Channel does not have a subscriber button or is missing subscriber info
# 4: psalm
# Channel does not have a subscriber button or is missing subscriber info
# 5: nikkiblackketter
# Channel does not have a subscriber button or is missing subscriber info
# 6: Threedogg
# Channel does not have a subscriber button or is missing subscriber info
# 7: Neenoh
# Channel does not have a subscriber button or is missing subscriber info
# 8: MilagroGramz
# Channel does not have a subscriber button or is missing subscriber info
# 9: BossLadyLily
# 10: chrisudalla
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 164
# --------------------
# 1: TwelveRivers
# Channel does not have a subscriber button or is missing subscriber info
# 2: Sommerset
# Channel does not have a subscriber button or is missing subscriber info
# 3: Diffensive
# Channel does not have a subscriber button or is missing subscriber info
# 4: mercenarygaming
# Channel does not have a subscriber button or is missing subscriber info
# 5: propunker
# Channel does not have a subscriber button or is missing subscriber info
# 6: BonsaiBroz
# Channel does not have a subscriber button or is missing subscriber info
# 7: janix
# 8: slamjam_
# Channel does not have a subscriber button or is missing subscriber info
# 9: Bean
# Channel does not have a subscriber button or is missing subscriber info
# 10: Raelilblack
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 165
# --------------------
# 1: CitizenS9
# 2: Rated
# Channel does not have a subscriber button or is missing subscriber info
# 3: Redshell
# Channel does not have a subscriber button or is missing subscriber info
# 4: Zayt
# Channel does not have a subscriber button or is missing subscriber info
# 5: JaredFPS
# 6: Bptz
# Channel does not have a subscriber button or is missing subscriber info
# 7: WorldofTanks
# Channel does not have a subscriber button or is missing subscriber info
# 8: FailArmy
# Channel does not have a subscriber button or is missing subscriber info
# 9: Dashy
# Channel does not have a subscriber button or is missing subscriber info
# 10: AliasV
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 166
# --------------------
# 1: JenaUrf
# Channel does not have a subscriber button or is missing subscriber info
# 2: eggsoup
# Channel does not have a subscriber button or is missing subscriber info
# 3: NerdCubed
# Channel does not have a subscriber button or is missing subscriber info
# 4: RuneScape
# Channel does not have a subscriber button or is missing subscriber info
# 5: ChimneyCakes
# Channel does not have a subscriber button or is missing subscriber info
# 6: Trynet123
# 7: MegTurney
# Channel does not have a subscriber button or is missing subscriber info
# 8: lunathemagikarp
# Channel does not have a subscriber button or is missing subscriber info
# 9: sokacito
# Channel does not have a subscriber button or is missing subscriber info
# 10: MintMadCow
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 167
# --------------------
# 1: AngelMelly
# 2: TheSteveStream
# Channel does not have a subscriber button or is missing subscriber info
# 3: J_Alexander_HS
# Channel does not have a subscriber button or is missing subscriber info
# 4: iainLee
# Channel does not have a subscriber button or is missing subscriber info
# 5: CCP
# Channel does not have a subscriber button or is missing subscriber info
# 6: OvidiuZ94
# Channel does not have a subscriber button or is missing subscriber info
# 7: ShopmasterTV
# Channel does not have a subscriber button or is missing subscriber info
# 8: Umplify
# Channel does not have a subscriber button or is missing subscriber info
# 9: ChrisRM22
# Channel does not have a subscriber button or is missing subscriber info
# 10: blondinkaia
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 168
# --------------------
# 1: RoadNationOfficial
# Channel does not have a subscriber button or is missing subscriber info
# 2: Grizz
# Channel does not have a subscriber button or is missing subscriber info
# 3: LuckyGhostTV
# Channel does not have a subscriber button or is missing subscriber info
# 4: theonlymonto
# Channel does not have a subscriber button or is missing subscriber info
# 5: Lana_Lux
# Channel does not have a subscriber button or is missing subscriber info
# 6: BaLoRi
# Channel does not have a subscriber button or is missing subscriber info
# 7: Wolfy2032
# Channel does not have a subscriber button or is missing subscriber info
# 8: FFTBattleground
# Channel does not have a subscriber button or is missing subscriber info
# 9: catsen
# 10: SimCopter1
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 169
# --------------------
# 1: deviiiiiiiiii
# Channel does not have a subscriber button or is missing subscriber info
# 2: kittyk838
# Channel does not have a subscriber button or is missing subscriber info
# 3: Sizz
# Channel does not have a subscriber button or is missing subscriber info
# 4: vegidoutlaw
# Channel does not have a subscriber button or is missing subscriber info
# 5: Kwitty23
# Channel does not have a subscriber button or is missing subscriber info
# 6: ElainaExe
# 7: jihita
# Channel does not have a subscriber button or is missing subscriber info
# 8: quake
# Channel does not have a subscriber button or is missing subscriber info
# 9: Snake_Nade
# Channel does not have a subscriber button or is missing subscriber info
# 10: ArcSystemWorksU
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 170
# --------------------
# 1: IvySky
# 2: CrunchyEggrollz
# Channel does not have a subscriber button or is missing subscriber info
# 3: LoochyTV
# Channel does not have a subscriber button or is missing subscriber info
# 4: Bububu
# Channel does not have a subscriber button or is missing subscriber info
# 5: HisandHersLive
# Channel does not have a subscriber button or is missing subscriber info
# 6: lolmalice
# Channel does not have a subscriber button or is missing subscriber info
# 7: TBJZL
# Channel does not have a subscriber button or is missing subscriber info
# 8: ster
# Channel does not have a subscriber button or is missing subscriber info
# 9: Benny
# Channel does not have a subscriber button or is missing subscriber info
# 10: SmittyStone
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 171
# --------------------
# 1: HazThaGreat
# Channel does not have a subscriber button or is missing subscriber info
# 2: CletusBueford
# Channel does not have a subscriber button or is missing subscriber info
# 3: imrosen
# Channel does not have a subscriber button or is missing subscriber info
# 4: Kalamazi
# 5: Kinamazing
# Channel does not have a subscriber button or is missing subscriber info
# 6: yourgotocent
# Channel does not have a subscriber button or is missing subscriber info
# 7: Barnacules
# Channel does not have a subscriber button or is missing subscriber info
# 8: TopGunn7
# 9: ookayallday
# Channel does not have a subscriber button or is missing subscriber info
# 10: YBNMike
#
#
# Beginning page: 172
# --------------------
# 1: Larsfest
# Channel does not have a subscriber button or is missing subscriber info
# 2: lethamyr_rl
# Channel does not have a subscriber button or is missing subscriber info
# 3: IamBushtv
# 4: eebern
# Channel does not have a subscriber button or is missing subscriber info
# 5: TeamBeyondnet
# Channel does not have a subscriber button or is missing subscriber info
# 6: grilthegamer
# Channel does not have a subscriber button or is missing subscriber info
# 7: RichHomieQuinn
# Channel does not have a subscriber button or is missing subscriber info
# 8: ZeplaHQ
# Channel does not have a subscriber button or is missing subscriber info
# 9: dinossindgeil
# Channel does not have a subscriber button or is missing subscriber info
# 10: Voxy
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 173
# --------------------
# 1: CODCode904
# ...
# 9: FarmerJohn
# Channel does not have a subscriber button or is missing subscriber info
# 10: DougDougW
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 196
# --------------------
# 1: TweaK
# Channel does not have a subscriber button or is missing subscriber info
# 2: Livibee
# Channel does not have a subscriber button or is missing subscriber info
# 3: XenosysVex
# Channel does not have a subscriber button or is missing subscriber info
# 4: GFuelEnergy
# Channel does not have a subscriber button or is missing subscriber info
# 5: iRiskpvp
# 6: Covertgoblue
# Channel does not have a subscriber button or is missing subscriber info
# 7: DistantCoder
# 8: AfroSenjuTV
# Channel does not have a subscriber button or is missing subscriber info
# 9: Freakazoid
# 10: perplexity
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 197
# --------------------
# 1: Octopimp
# Channel does not have a subscriber button or is missing subscriber info
# 2: ScottJund
# Channel does not have a subscriber button or is missing subscriber info
# 3: Medic1556
# 4: mkleossb
# Channel does not have a subscriber button or is missing subscriber info
# 5: Zulp
# Channel does not have a subscriber button or is missing subscriber info
# 6: TylorTurner
# Channel does not have a subscriber button or is missing subscriber info
# 7: carabeanz
# Channel does not have a subscriber button or is missing subscriber info
# 8: zedvile
# Channel does not have a subscriber button or is missing subscriber info
# 9: EnNopp112
# Channel does not have a subscriber button or is missing subscriber info
# 10: CarryBarry_
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 198
# --------------------
# 1: dorkibear
# Channel does not have a subscriber button or is missing subscriber info
# 2: zoasty
# Channel does not have a subscriber button or is missing subscriber info
# 3: Hey_Jase
# Channel does not have a subscriber button or is missing subscriber info
# 4: RayditzFN
# Channel does not have a subscriber button or is missing subscriber info
# 5: hashtag_shawrey
# Channel does not have a subscriber button or is missing subscriber info
# 6: rendogtv
# Channel does not have a subscriber button or is missing subscriber info
# 7: Dekkster
# Channel does not have a subscriber button or is missing subscriber info
# 8: burgerwarrior24
# Channel does not have a subscriber button or is missing subscriber info
# 9: SandyRavage
# Channel does not have a subscriber button or is missing subscriber info
# 10: Lost_Pause
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 199
# --------------------
# 1: Jawsh
# 2: SONII
# Channel does not have a subscriber button or is missing subscriber info
# 3: Harambe
# Channel does not have a subscriber button or is missing subscriber info
# 4: Picco
# Channel does not have a subscriber button or is missing subscriber info
# 5: SilenceeDGAF
# Channel does not have a subscriber button or is missing subscriber info
# 6: YourPalRoss
# Channel does not have a subscriber button or is missing subscriber info
# 7: ntreality
# Channel does not have a subscriber button or is missing subscriber info
# 8: BioHackTV
# Channel does not have a subscriber button or is missing subscriber info
# 9: Leonjiro
# Channel does not have a subscriber button or is missing subscriber info
# 10: Strawburry17plays
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 200
# --------------------
# 1: ImAllexx
# Channel does not have a subscriber button or is missing subscriber info
# 2: wallah
# Channel does not have a subscriber button or is missing subscriber info
# 3: x821754A45x8
# Channel does not have a subscriber button or is missing subscriber info
# 4: SheefGG
# Channel does not have a subscriber button or is missing subscriber info
# 5: DuelLinksEntertainment
# Channel does not have a subscriber button or is missing subscriber info
# 6: Spammiej
# Channel does not have a subscriber button or is missing subscriber info
# 7: YoDaTV
# Channel does not have a subscriber button or is missing subscriber info
# 8: mikelabelle
# Channel does not have a subscriber button or is missing subscriber info
# 9: ul_xx10
# Channel does not have a subscriber button or is missing subscriber info
# 10: MTGNerdGirl
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 201
# --------------------
# 1: Tiqqlethis
# Channel does not have a subscriber button or is missing subscriber info
# 2: punkdagod
# Channel does not have a subscriber button or is missing subscriber info
# 3: Braction6
# Channel does not have a subscriber button or is missing subscriber info
# 4: EdEMonster
# Channel does not have a subscriber button or is missing subscriber info
# 5: PKMNcast
# 6: xcudi
# Channel does not have a subscriber button or is missing subscriber info
# 7: AYYJAYY
# Channel does not have a subscriber button or is missing subscriber info
# 8: Pobelter
# 9: djbellafiasco
# Channel does not have a subscriber button or is missing subscriber info
# 10: yourewelcome
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 202
# --------------------
# 1: ChessKid
# Channel does not have a subscriber button or is missing subscriber info
# 2: Rhymestyle
# Channel does not have a subscriber button or is missing subscriber info
# 3: tt_wwwlll
# Channel does not have a subscriber button or is missing subscriber info
# 4: Markstrom
# 5: Weest
# Channel does not have a subscriber button or is missing subscriber info
# 6: plumbella
# Channel does not have a subscriber button or is missing subscriber info
# 7: Dunder_Mifflin_TV
# Channel does not have a subscriber button or is missing subscriber info
# 8: RagingRavage
# Channel does not have a subscriber button or is missing subscriber info
# 9: MixelPlx
# Channel does not have a subscriber button or is missing subscriber info
# 10: GirlfriendReviews
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 203
# --------------------
# 1: DiegoContra
# 2: MTGGoldfish
# Channel does not have a subscriber button or is missing subscriber info
# 3: PWNSTARZdotCOM
# Channel does not have a subscriber button or is missing subscriber info
# 4: dekillsage
# Channel does not have a subscriber button or is missing subscriber info
# 5: jaystreazy
# 6: FACEIT TV
# Channel does not have a subscriber button or is missing subscriber info
# 7: ChillboBagginz
# Channel does not have a subscriber button or is missing subscriber info
# 8: Nikez
# Channel does not have a subscriber button or is missing subscriber info
# 9: kittychipz
# 10: ErickKhanTV
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 204
# --------------------
# 1: AngieVee
# Channel does not have a subscriber button or is missing subscriber info
# 2: alanaolson1983
# Channel does not have a subscriber button or is missing subscriber info
# 3: PTNewsNetwork
# Channel does not have a subscriber button or is missing subscriber info
# 4: Zetalot
# Channel does not have a subscriber button or is missing subscriber info
# 5: WatsonComedy
# Channel does not have a subscriber button or is missing subscriber info
# 6: TheCHUGS
# Channel does not have a subscriber button or is missing subscriber info
# 7: ScomoTV
# Channel does not have a subscriber button or is missing subscriber info
# 8: MrGM
# Channel does not have a subscriber button or is missing subscriber info
# 9: LigaPro_3
# Channel does not have a subscriber button or is missing subscriber info
# 10: bunny_gif
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 205
# --------------------
# 1: CeeCee_Lia
# Channel does not have a subscriber button or is missing subscriber info
# 2: CastAwaysTV
# Channel does not have a subscriber button or is missing subscriber info
# 3: AweCoop
# Channel does not have a subscriber button or is missing subscriber info
# 4: avivasofia
# Channel does not have a subscriber button or is missing subscriber info
# 5: shockist
# Channel does not have a subscriber button or is missing subscriber info
# 6: BHOFILMS
# Channel does not have a subscriber button or is missing subscriber info
# 7: maximarex03
# Channel does not have a subscriber button or is missing subscriber info
# 8: Luminumn
# Channel does not have a subscriber button or is missing subscriber info
# 9: derrekow
# Channel does not have a subscriber button or is missing subscriber info
# 10: AvaGG
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 206
# --------------------
# 1: RNCesus
# 2: floofyeosang
# Channel does not have a subscriber button or is missing subscriber info
# 3: StremZ
# 4: rioluTM
# Channel does not have a subscriber button or is missing subscriber info
# 5: bully
# 6: Just_Relax_Kid
# 7: geo874
# Channel does not have a subscriber button or is missing subscriber info
# 8: DSGamingGC
# Channel does not have a subscriber button or is missing subscriber info
# 9: iHasCupquake
# Channel does not have a subscriber button or is missing subscriber info
# 10: ESEA
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 207
# --------------------
# 1: itzwarsz
# Channel does not have a subscriber button or is missing subscriber info
# 2: just_ouro
# Channel does not have a subscriber button or is missing subscriber info
# 3: maximarex04
# Channel does not have a subscriber button or is missing subscriber info
# 4: FeFe
# Channel does not have a subscriber button or is missing subscriber info
# 5: LinusTech
# Channel does not have a subscriber button or is missing subscriber info
# 6: nanolite
# Channel does not have a subscriber button or is missing subscriber info
# 7: stunt
# Channel does not have a subscriber button or is missing subscriber info
# 8: sodyz
# Channel does not have a subscriber button or is missing subscriber info
# 9: Lassiz
# Channel does not have a subscriber button or is missing subscriber info
# 10: Aphostle
# Channel does not have a subscriber button or is missing subscriber info
#
#
# Beginning page: 208
# --------------------
# 1: Erick_Dota
# Channel does not have a subscriber button or is missing subscriber info
# 2: Shadybunny
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-fcd441713b12> in <module>
#       9 # completed = [] # starting new
#      10 completed = [x.split(".json")[0] for x in next(os.walk("data/streamer_info"))[2]] # resuming
# ---> 11 get_multiple_pages(driver, starting_page=113, num_pages=250-113, completed=completed)
#
# <ipython-input-16-f82e5eff0ab6> in get_multiple_pages(driver, starting_page, num_pages, completed)
#      14 #         print("Pages remaining:", num_pages-starting_page-page_count+1)
#      15         print("-"*20)
# ---> 16         get_one_page(driver, completed)
#      17         next_page = driver.find_element_by_xpath('.//ul[contains(@class,"pagination")]/li[2]/a')
#      18         driver.execute_script("arguments[0].scrollIntoView()", next_page)
#
# <ipython-input-15-6a4d676eb610> in get_one_page(driver, completed)
#      19         # go to streamer page
#      20         driver.execute_script("arguments[0].scrollIntoView()", link)
# ---> 21         link.click()
#      22         escape_ad(driver)
#      23         rand_sleep()
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~\Anaconda3\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      78         else:
#      79             return self.request_encode_body(
# ---> 80                 method, url, fields=fields, headers=headers, **urlopen_kw
#      81             )
#      82
#
# ~\Anaconda3\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     169         extra_kw.update(urlopen_kw)
#     170
# --> 171         return self.urlopen(method, url, **extra_kw)
#
# ~\Anaconda3\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     328             response = conn.urlopen(method, url, **kw)
#     329         else:
# --> 330             response = conn.urlopen(method, u.request_uri, **kw)
#     331
#     332         redirect_location = redirect and response.get_redirect_location()
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     670                 body=body,
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#     674
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                     # Python 3 (including for exceptions like SystemExit).
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     423             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     414                 # Python 3
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#     418                     # Remove the TypeError from the exception chain in
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1342         try:
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#    1346                 self.close()
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# ## Counting languages

# %%
datadir = "data/streamer_info"
langs = []
for fname in next(os.walk(datadir))[2]:
    with open(datadir + "/" + fname, "r") as f:
        x = json.load(f)
        profile = x["Profile"]
        for d in profile:
            if "Language" in d:
                langs.append(d["Language"])

ct = Counter(langs)
print("Number of streamers", len(langs))
print("Number of unique languages", len(ct))
print("\nLanguage counts\n" + "-"*50 + "\n", ct.most_common(), "\n", "-"*50)
# Out:
# Number of streamers 3154
# Number of unique languages 28
#
# Language counts
# --------------------------------------------------
#  [('English', 2030), ('Spanish', 214), ('Portuguese', 182), ('Russian', 133), ('French', 117), ('Korean', 117), ('German', 109), ('Chinese', 48), ('Italian', 46), ('Turkish', 37), ('Polish', 35), ('Japanese', 28), ('Thai', 12), ('Czech', 11), ('Arabic', 8), ('Finnish', 6), ('Hungarian', 4), ('Unknown', 3), ('Slovak', 2), ('Greek', 2), ('Swedish', 2), ('Danish', 2), ('Romanian', 1), ('Malay', 1), ('Indonesian', 1), ('Hindi', 1), ('Vietnamese', 1), ('Dutch', 1)]
#  --------------------------------------------------

# %% [markdown]
# ## Recoding non-ascii usernames (i.e. Chinese characters)

# %%
usernames = [x.split(".json")[0] for x in next(os.walk("data/streamer_info"))[2]]
with open("data/usernames_archive/top-3154-hoursWatched-allLanguages.txt", "w", encoding="utf-8") as f:
    f.write("\n".join(usernames))

# %%
usernames = [x.split(".json")[0] for x in next(os.walk("data/streamer_info"))[2]]
def is_ascii(s):
    return all(ord(c) < 128 for c in s)

non_ascii_names = [x for x in usernames if not is_ascii(x.replace("_","").replace(" ",""))]
non_ascii_names[:10]
# Out:
# ['_연두부_',
#  'ぐちつぼ',
#  'しゃるる',
#  'たぬき忍者',
#  'むかい',
#  'らいじん',
#  'らっだぁ',
#  'ウェザーニュース',
#  'スタンミ',
#  '世界の屁こき隊']

# %% [markdown]
# ### Attempt 1: search TwitchTracker for username

# %%
# initialize driver
driver = webdriver.Chrome('./chromedriver.exe')

def write_data(name, non_ascii):
    with open("data/non_ascii_to_ascii.txt", "a+", encoding="utf-8") as f:
        f.write("%s %s\n" % (name, non_ascii))


for i,name in enumerate(non_ascii_names):
    print("Completed:", i/len(non_ascii_names))
    url = "https://twitchtracker.com/search?q=%s" % name
    driver.get(url)
    time.sleep(4)
    search_results = driver.find_elements_by_xpath('.//table[@id="channels-result"]/tbody/tr[1]//a[contains(text(),"Visit")]')
        
    if len(search_results) == 0:
        print("No search results:", name)
        write_data(name, "NA")
        continue

    search_results[0].click()
    time.sleep(4)
    
    try:
        title = driver.find_element_by_xpath('.//h4[text()="%s"]' % name).text
    except NoSuchElementException:
        write_data(name, "NA")
    else:
        if title != name:
            write_data(name, "NA")
        else:
            try:
                subtitle = driver.find_element_by_xpath('.//div[@id="app-title"]/small').text
            except NoSuchElementException:
                print("No subtitle for:", name)
                write_data(name, "NA")
            else:
                write_data(name, subtitle)   
    finally:
        driver.back()
        time.sleep(3)
# Out:
# Completed: 0.0
# Completed: 0.00625
# Completed: 0.0125
# Completed: 0.01875
# Completed: 0.025
# Completed: 0.03125
# Completed: 0.0375
# Completed: 0.04375
# Completed: 0.05
# Completed: 0.05625
# Completed: 0.0625
# Completed: 0.06875
# Completed: 0.075
# Completed: 0.08125
# Completed: 0.0875
# No search results: 大丸
# Completed: 0.09375
# No search results: 嬌兔
# Completed: 0.1
# Completed: 0.10625
# No search results: 小舞
# Completed: 0.1125
# Completed: 0.11875
# No search results: 懶貓
# Completed: 0.125
# No search results: 接接
# Completed: 0.13125
# Completed: 0.1375
# Completed: 0.14375
# No search results: 殺梗
# Completed: 0.15
# Completed: 0.15625
# No search results: 湯米
# Completed: 0.1625
# Completed: 0.16875
# Completed: 0.175
# Completed: 0.18125
# No search results: 球球
# Completed: 0.1875
# No search results: 紀囧
# Completed: 0.19375
# Completed: 0.2
# No search results: 羅傑
# Completed: 0.20625
# No search results: 老婆
# Completed: 0.2125
# No search results: 老皮
# Completed: 0.21875
# No search results: 薛喜
# Completed: 0.225
# No search results: 蛇足
# Completed: 0.23125
# Completed: 0.2375
# Completed: 0.24375
# No search results: 貝克
# Completed: 0.25
# Completed: 0.25625
# Completed: 0.2625
# No search results: 踢虧
# Completed: 0.26875
# No search results: 逼比
# Completed: 0.275
# No search results: 阿土
# Completed: 0.28125
# No search results: 阿寧
# Completed: 0.2875
# No search results: 阿津
# Completed: 0.29375
# Completed: 0.3
# No search results: 龜狗
# Completed: 0.30625
# Completed: 0.3125
# Completed: 0.31875
# No search results: 강지
# Completed: 0.325
# No search results: 강퀴
# Completed: 0.33125
# Completed: 0.3375
# Completed: 0.34375
# Completed: 0.35
# Completed: 0.35625
# Completed: 0.3625
# Completed: 0.36875
# Completed: 0.375
# Completed: 0.38125
# Completed: 0.3875
# Completed: 0.39375
# Completed: 0.4
# No search results: 김도
# Completed: 0.40625
# Completed: 0.4125
# Completed: 0.41875
# Completed: 0.425
# No search results: 까막
# Completed: 0.43125
# Completed: 0.4375
# No search results: 꽃핀
# Completed: 0.44375
# Completed: 0.45
# Completed: 0.45625
# No search results: 다주
# Completed: 0.4625
# Completed: 0.46875
# Completed: 0.475
# Completed: 0.48125
# Completed: 0.4875
# Completed: 0.49375
# No search results: 랄로
# Completed: 0.5
# Completed: 0.50625
# Completed: 0.5125
# No search results: 룩삼
# Completed: 0.51875
# Completed: 0.525
# Completed: 0.53125
# Completed: 0.5375
# Completed: 0.54375
# No search results: 머독
# Completed: 0.55
# Completed: 0.55625
# No search results: 무굴
# Completed: 0.5625
# No search results: 배돈
# Completed: 0.56875
# Completed: 0.575
# Completed: 0.58125
# No search results: 삐부
# Completed: 0.5875
# Completed: 0.59375
# No search results: 서넹
# Completed: 0.6
# Completed: 0.60625
# No search results: 선바
# Completed: 0.6125
# Completed: 0.61875
# Completed: 0.625
# Completed: 0.63125
# Completed: 0.6375
# No search results: 쉐리
# Completed: 0.64375
# Completed: 0.65
# Completed: 0.65625
# Completed: 0.6625
# Completed: 0.66875
# No search results: 쌍베
# Completed: 0.675
# No search results: 악어
# Completed: 0.68125
# Completed: 0.6875
# Completed: 0.69375
# No search results: 얍얍
# Completed: 0.7
# No search results: 양띵
# Completed: 0.70625
# Completed: 0.7125
# Completed: 0.71875
# Completed: 0.725
# Completed: 0.73125
# No search results: 오킹
# Completed: 0.7375
# Completed: 0.74375
# Completed: 0.75
# Completed: 0.75625
# Completed: 0.7625
# Completed: 0.76875
# Completed: 0.775
# Completed: 0.78125
# Completed: 0.7875
# Completed: 0.79375
# No search results: 자동
# Completed: 0.8
# Completed: 0.80625
# Completed: 0.8125
# No search results: 중력
# Completed: 0.81875
# Completed: 0.825
# Completed: 0.83125
# Completed: 0.8375
# Completed: 0.84375
# Completed: 0.85
# Completed: 0.85625
# Completed: 0.8625
# No search results: 케인
# Completed: 0.86875
# Completed: 0.875
# Completed: 0.88125
# Completed: 0.8875
# Completed: 0.89375
# Completed: 0.9
# No search results: 트할
# Completed: 0.90625
# Completed: 0.9125
# No search results: 포셔
# Completed: 0.91875
# No search results: 푸사
# Completed: 0.925
# Completed: 0.93125
# Completed: 0.9375
# Completed: 0.94375
# Completed: 0.95
# No search results: 핑맨
# Completed: 0.95625
# Completed: 0.9625
# Completed: 0.96875
# Completed: 0.975
# Completed: 0.98125
# Completed: 0.9875
# No search results: 헤징
# Completed: 0.99375

# %% [markdown]
# ### Attempt 2: search Twitch.tv website for username

# %%
# initialize driver
driver = webdriver.Chrome('./chromedriver.exe')

df = pd.read_csv("data/non_ascii_to_ascii.txt", delimiter=" ", header=None, names=["non_ascii","ascii"])
complete = df.loc[~df["ascii"].isna()]
incomplete = df.loc[df["ascii"].isna()]
for row in incomplete.iterrows():
    name = row[1]["non_ascii"]
    url = "https://www.twitch.tv/search?term=%s" % name
    driver.get(url)
    time.sleep(6)
    
    try:
        search_results = driver.find_elements_by_xpath('.//div[contains(@class,"search-result")]/a')
    except:
        print("error getting", name)
    else:
        row[1]["ascii"] = search_results[0].get_attribute("href").split("/")[-1]

incomplete.head()
# Out:
#    non_ascii         ascii
# 14        大丸  wtf_winds123
# 15        嬌兔         zrush
# 17        小舞      nein1203
# 19        懶貓     failverde
# 20        接接         godjj

# %%
df_concat = pd.concat([complete, incomplete], axis=0)
df_concat.to_csv("data/non_ascii_to_ascii.csv", index=False)
df_concat.isna().sum()
# Out:
# non_ascii    0
# ascii        0
# dtype: int64

# %% [markdown]
# ### Recoding file names in streamer_logos/ and games/

# %%
code_df = pd.read_csv("data/non_ascii_to_ascii.csv")
code = {x:y for x,y in zip(code_df["non_ascii"], code_df["ascii"])}

def rename(src, dst):
    if os.path.exists(src):
        os.rename(src, dst)
        
for name in non_ascii_names:
    with open("data/streamer_info/%s.json" % name, "r", encoding="utf-8") as f:
        data = json.load(f)
        data["Profile"][0]["Name"] = code[name]
        
    with open("data/streamer_info/%s.json" % name, "w", encoding="utf-8") as f:
        json.dump(data, f)
    
    rename("data/streamer_info/%s.json" % name, "data/streamer_info/%s.json" % code[name])
    rename("data/streamer_logos/%s.png" % name, "data/streamer_logos/%s.png" % code[name])
    rename("data/games/%s.csv" % name, "data/games/%s.csv" % code[name])
    
df = pd.read_csv("data/streamer_info.csv")
df["name"] = df["name"].replace(code)
df.sort_values("name").to_csv("data/streamer_info.csv", index=False)
    
for fname in glob("data/usernames_archive/*"):
    with open(fname, "r", encoding="utf-8") as f:
        data = f.read().split("\n")
    with open(fname, "w", encoding="utf-8") as f:
        f.write( "\n".join(list(map(lambda x: x if x not in code else code[x], data))) )

# %% [markdown]
# ## Reformatting data & removing subscriber data

# %%
def reformat_performance_data(x,idx):
    if idx == 5:
        val = float(list(x["Performance"][idx].values())[0][0].replace(",",""))
    else:
        val = int(round(float(list(x["Performance"][idx].values())[0][0].replace(",",""))))
    
#     contrast = list(x["Performance"][idx].values())[0][1].replace(",", "").strip()
#     if not contrast:
#         raw_inc = "NA"
        
#     elif "|" in contrast:
#         sign = contrast.split("|")[0][0]
#         if idx == 5:
#             raw_inc = float(eval(contrast.split("|")[0]))
#         else:
#             raw_inc = int(eval(contrast.split("|")[0]))
#     else:
#         if idx == 5:
#             raw_inc = float(eval(contrast))
#         else:
            
#             raw_inc = int(eval(contrast))
    
#     return val, raw_inc
    return val

def reformat_summary_data(x, idx):
    val = int(float(list(x["Summary"][idx].values())[0].replace(",", "")))
    return val

def reformat_profile_data(x, idx):
    if idx == 1:
        val = int("".join([c for c in list(x["Profile"][idx].values())[0] if c.isdigit()]))
    elif idx == 3:
        string = list(x["Profile"][idx].values())[0]
#         val = datetime.strptime(string, "%b %d, %Y").strftime("%Y-%m-%d")
        val = datetime.strptime(string, "%b %d, %Y").strftime("%Y-%m-%d")
    else:
        val = list(x["Profile"][idx].values())[0]
    return val

def reformat_stream_data(x, idx):
    if idx == 0:
        val = float(list(x["Average stream"][idx].values())[0])
    elif idx == 1:
        string = list(x["Average stream"][idx].values())[0].replace(",","")
        if string[-1] == "K":
            val = int(float(string[:-1])*10**3)
        elif string[-1] == "M":
            val = int(float(string[:-1])*10**6)
        else:
            val = int(string)
    elif idx == 2:
        val = int(list(x["Average stream"][idx].values())[0].replace(",", ""))
    else:
        string = list(x["Average stream"][idx].values())[0].replace(",","")
        if not string[-3:] == "hrs":
            with open("errors.txt", "a+") as g:
                g.write("Error" + list(x["Profile"][0].values())[0])
        else:
            val = eval(string[:-3])

    return val

def reformat_metrics_data(x, idx):
    if idx == 0:
        val = float(eval(list(x["Various metrics"][idx].values())[0].split("/")[0]))
    elif idx == 1:
        val = int(list(x["Various metrics"][idx].values())[0])
    else:
        val = list(x["Various metrics"][idx].values())[0]
    return val

# %%
def reformat_user(x):
    data = []
    for i in range(len(x["Performance"])):
        data.append(reformat_performance_data(x,i))
#         val, raw_inc = reformat_performance_data(x,i)
#         data.extend([val, raw_inc])

    for i in range(len(x["Summary"])):
        data.append(reformat_summary_data(x,i))
    for i in range(len(x["Profile"])):
        data.append(reformat_profile_data(x,i))
    for i in range(len(x["Average stream"])):
        data.append(reformat_stream_data(x,i))
    for i in range(len(x["Various metrics"])):
        data.append(reformat_metrics_data(x,i))
    return data

all_data = []
for fname in next(os.walk("data/streamer_info"))[2]:
    with open("data/streamer_info/" + fname, "r") as f:
        x = json.load(f)
#         print(x["Profile"][0]["Name"])
        all_data.append(reformat_user(x))
        

cols = [
    'rec_hours_streamed',
    'rec_hours_streamed_inc',
    'rec_avg_viewers',
    'rec_avg_viewers_inc',
    'rec_peak_viewers',
    'rec_peak_viewers_inc',
    'rec_hours_watched',
    'rec_hours_watched_inc',
    'rec_followers_gained',
    'rec_followers_gained_inc',
    'rec_followers_per_hour',
    'rec_followers_per_hour_inc',
    'rec_views_gained',
    'rec_views_gained_inc',
    'rec_number_of_streams',
    'rec_number_of_streams_inc',
    'total_hours_streamed',
    'career_peak_viewers',
    'total_followers',
    'total_views',
    'name',
    'ranking',
    'language',
    'creation_date',
    'partnered',
    'mature_content',
    'channel_description',
    'avg_games_streamed',
    'avg_views_gained',
    'avg_followers_gained',
    'avg_stream_duration',
    'active_days_per_week',
    'unique_games_played',
    'stream_start',
    'total_activity']
cols = [c for c in cols if c[-4:] != "_inc"]

df = pd.DataFrame(data=all_data, columns=cols)
df = df.set_index("name").reset_index()

# %%
df.shape
# Out:
# (3154, 27)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(df[df["name"]=="shroud"])
# Out:
#         name  rec_hours_streamed  rec_avg_viewers  rec_peak_viewers  \
# 2334  shroud                 565            30577            516289
#
#       rec_hours_watched  rec_followers_gained  rec_followers_per_hour  \
# 2334           17304543               1182816                  2090.0
#
#       rec_views_gained  rec_number_of_streams  total_hours_streamed  \
# 2334          32210765                     64                  8071
#
#       career_peak_viewers  total_followers  total_views  ranking language  \
# 2334               516289          8395134    399605110       43  English
#
#      creation_date partnered mature_content channel_description  \
# 2334    2012-11-03       Yes             No       I'm back baby
#
#       avg_games_streamed  avg_views_gained  avg_followers_gained  \
# 2334                 2.3            389000                  8005
#
#       avg_stream_duration  active_days_per_week  unique_games_played  \
# 2334                  8.1                   4.9                  227
#
#      stream_start     total_activity
# 2334        19:30  1000 of 1442 days

# %%
df.to_csv("data/streamer_info.csv", mode="w", index=False)

# %% [markdown]
# ## English streams

# %%
df_eng = df.loc[(df["language"]=="English") & (~df["name"].isin(non_ascii_names))]

# %%
df_eng.to_csv("data/streamer_info_eng.csv", mode="w", index=False)
